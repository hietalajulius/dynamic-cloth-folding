# %%
# !python sac_training.py --run=1 \
--title=her-sac-validation \
--train_steps=100 \
--num_epochs=50 \
--her_percent=0.8 \
--env_name=Cloth-v1 \
--task=sideways \
--image_training=1 \
--buffer_size=100000 \
--randomize_params=1 \
--seed=1 \
--profile=1
# Out:
# No personal conf_private.py found.
# doodad not detected
# Args Namespace(buffer_size=100000, distance_threshold=0.05, env_name='Cloth-v1', eval_steps=500, her_percent=0.8, image_size=84, image_training=1, max_advance=0.05, max_path_length=50, min_expl_steps=1000, num_cycles=100, num_epochs=50, profile=1, randomize_geoms=0, randomize_params=1, rgb=1, run=1, seed=1, strict=1, task='sideways', title='her-sac-validation', train_steps=100, uniform_jnt_tend=1)
# Training with GPU
# 2020-10-25 14:07:14.049828 EET | Variant:
# 2020-10-25 14:07:14.050036 EET | {
#   "algorithm": "SAC",
#   "layer_size": 256,
#   "trainer_kwargs": {
#     "discount": 0.99,
#     "soft_target_tau": 0.005,
#     "target_update_period": 1,
#     "policy_lr": 0.0003,
#     "qf_lr": 0.0003,
#     "reward_scale": 1,
#     "use_automatic_entropy_tuning": true
#   },
#   "path_collector_kwargs": {
#     "additional_keys": "['robot_observation']"
#   },
#   "policy_kwargs": {
#     "input_width": 84,
# ...
