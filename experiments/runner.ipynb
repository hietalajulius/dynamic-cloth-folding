# %%
# !python sac_diagonal.py --run=2 --title=no-her-sac-diagonal-strict-no-learn-grasp --train_steps=100 --num_epochs=100 --her_percent=0.0
# Out:
# objc[98791]: Class GLFWApplicationDelegate is implemented in both /Users/juliushietala/.mujoco/mujoco200/bin/libglfw.3.dylib (0x1275b3778) and /Users/juliushietala/Desktop/Robotics/rlkit_env/lib/python3.7/site-packages/glfw/libglfw.3.dylib (0x1276e66e8). One of the two will be used. Which one is undefined.
# objc[98791]: Class GLFWWindowDelegate is implemented in both /Users/juliushietala/.mujoco/mujoco200/bin/libglfw.3.dylib (0x1275b3700) and /Users/juliushietala/Desktop/Robotics/rlkit_env/lib/python3.7/site-packages/glfw/libglfw.3.dylib (0x1276e6710). One of the two will be used. Which one is undefined.
# objc[98791]: Class GLFWContentView is implemented in both /Users/juliushietala/.mujoco/mujoco200/bin/libglfw.3.dylib (0x1275b37a0) and /Users/juliushietala/Desktop/Robotics/rlkit_env/lib/python3.7/site-packages/glfw/libglfw.3.dylib (0x1276e6760). One of the two will be used. Which one is undefined.
# ...
