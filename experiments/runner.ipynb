# %%
# !python sac_sideways.py --run=1 --title=her-sac-sideways-strict-no-learn-grasp-randomize --train_steps=100 --num_epochs=50 --her_percent=0.8
# !python sac_sideways.py --run=2 --title=her-sac-sideways-strict-no-learn-grasp-randomize --train_steps=100 --num_epochs=50 --her_percent=0.8
# !python sac_sideways.py --run=3 --title=her-sac-sideways-strict-no-learn-grasp-randomize --train_steps=100 --num_epochs=50 --her_percent=0.8
# !python sac_sideways.py --run=4 --title=her-sac-sideways-strict-no-learn-grasp-randomize --train_steps=100 --num_epochs=50 --her_percent=0.8
# !python sac_sideways.py --run=5 --title=her-sac-sideways-strict-no-learn-grasp-randomize --train_steps=100 --num_epochs=50 --her_percent=0.8
# Out:
# objc[35961]: Class GLFWApplicationDelegate is implemented in both /Users/juliushietala/.mujoco/mujoco200/bin/libglfw.3.dylib (0x11b259778) and /Users/juliushietala/Desktop/robotics/rlkit_env/lib/python3.7/site-packages/glfw/libglfw.3.dylib (0x11b38c6e8). One of the two will be used. Which one is undefined.
# objc[35961]: Class GLFWWindowDelegate is implemented in both /Users/juliushietala/.mujoco/mujoco200/bin/libglfw.3.dylib (0x11b259700) and /Users/juliushietala/Desktop/robotics/rlkit_env/lib/python3.7/site-packages/glfw/libglfw.3.dylib (0x11b38c710). One of the two will be used. Which one is undefined.
# objc[35961]: Class GLFWContentView is implemented in both /Users/juliushietala/.mujoco/mujoco200/bin/libglfw.3.dylib (0x11b2597a0) and /Users/juliushietala/Desktop/robotics/rlkit_env/lib/python3.7/site-packages/glfw/libglfw.3.dylib (0x11b38c760). One of the two will be used. Which one is undefined.
# ...
