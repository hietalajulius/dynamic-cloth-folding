# %%
import pstats
from pstats import SortKey
KEY = SortKey.TIME
print(dir(SortKey))
# Out:
# ['CALLS', 'CUMULATIVE', 'FILENAME', 'LINE', 'NAME', 'NFL', 'PCALLS', 'STDNAME', 'TIME', '__class__', '__doc__', '__members__', '__module__']

# %%
p = pstats.Stats('notitle-run-1-stats-triton')
p.sort_stats(KEY).print_stats(100)
# Out:
# Sun Oct 25 14:08:24 2020    notitle-run-1-stats-triton
#
#          13280152 function calls (13182029 primitive calls) in 264.232 seconds
#
#    Ordered by: internal time
#    List reduced from 1038 to 100 due to restriction <100>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      2602   95.536    0.037   95.536    0.037 {method 'render' of 'mujoco_py.cymj.MjRenderContext' objects}
#     80800   94.291    0.001   94.291    0.001 {method 'step' of 'mujoco_py.cymj.MjSim' objects}
#      2602   20.649    0.008   20.649    0.008 {method 'read_pixels' of 'mujoco_py.cymj.MjRenderContext' objects}
#      1000   15.657    0.016   15.657    0.016 /home/hietalj4/robotics/rlkit/rlkit/data_management/obs_dict_replay_buffer.py:333(normalize_image)
#     15000    5.605    0.000    5.605    0.000 {method 'float' of 'torch._C._TensorBase' objects}
#     11055    5.106    0.000    5.106    0.000 {method 'to' of 'torch._C._TensorBase' objects}
# ...

# %%
p = pstats.Stats('notitle-run-1-stats')
p.sort_stats(KEY).print_stats(100)
# Out:
# Sun Oct 25 14:24:33 2020    notitle-run-1-stats
#
#          13280370 function calls (13182248 primitive calls) in 111.912 seconds
#
#    Ordered by: internal time
#    List reduced from 1038 to 100 due to restriction <100>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     80800   65.366    0.001   65.366    0.001 {method 'step' of 'mujoco_py.cymj.MjSim' objects}
#      1000    8.867    0.009    8.867    0.009 /home/clothmanip/robotics/rlkit/rlkit/data_management/obs_dict_replay_buffer.py:333(normalize_image)
#     11055    6.398    0.001    6.398    0.001 {method 'to' of 'torch._C._TensorBase' objects}
#     15000    3.066    0.000    3.066    0.000 {method 'float' of 'torch._C._TensorBase' objects}
#      2602    2.872    0.001    2.872    0.001 {method 'read_pixels' of 'mujoco_py.cymj.MjRenderContext' objects}
#      2502    2.490    0.001    2.491    0.001 {built-in method zeros}
# ...
