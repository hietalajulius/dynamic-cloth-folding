# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
current = 0
end = 1
filter_ = 0.03
vals = []
for _ in range(100):
    current = filter_*end + (1-filter_)*current
    vals.append(current)
    
plt.plot(vals, label="0.03")
print(np.max(vals))
current = 0
end = 1
filter_ = 0.015
vals = []
for _ in range(200):
    current = filter_*end + (1-filter_)*current
    vals.append(current)
print(np.max(vals)) 
plt.plot(vals, label="0.015")
plt.legend()
plt.show()
# Out:
# 1.0476922412820528
# 0.9513317086215096
